# %%
# !pip install tensorflow==2.0.0 -q
# Out:
#      |████████████████████████████████| 86.3MB 75kB/s
#      |████████████████████████████████| 3.8MB 39.5MB/s
#      |████████████████████████████████| 450kB 52.9MB/s
# ERROR: tensorflow-federated 0.12.0 has requirement tensorflow~=2.1.0, but you'll have tensorflow 2.0.0 which is incompatible.
# ERROR: tensorflow-federated 0.12.0 has requirement tensorflow-addons~=0.7.0, but you'll have tensorflow-addons 0.8.3 which is incompatible.

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.layers import SimpleRNN, Dense, Input 
from tensorflow.keras.models import Model

# %%
N = 1
T = 10
D = 3
K = 2

X = np.random.randn(N,T,D)

# %%
#Making the model

M = 5

i = Input(shape=(T,D))
x = SimpleRNN(M)(i)
x = Dense(K)(x)

model = Model(i,x)

# %%
yhat = model.predict(X)
print(yhat)
# Out:
# [[0.99004483 0.246528  ]]

# %%
a, b, c = model.layers[1].get_weights()
print("a: " + str(a.shape) + " b: " + str(b.shape) + " c: " + str(c.shape))
# Out:
# a: (3, 5) b: (5, 5) c: (5,)

# %%
wx, wh, bh = model.layers[1].get_weights()
wo, bo = model.layers[2].get_weights()

# %%
h_last = np.zeros(M)
x = X[0]
Yhat = []

for t in range(T):
  h = np.tanh(x[t].dot(wx) + h_last.dot(wh) + bh)
  y = h.dot(wo) + bo

  Yhat.append(y)
  h_last = h

print(Yhat[-1])
# Out:
# [0.99004492 0.24652804]
